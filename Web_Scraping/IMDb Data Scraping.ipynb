# %% [markdown]
# # Web Scraping Movie Data from the IMDb Website

# %%
# Custom function to scrape the top grossing n movies from desired year.

def scrape_movies(n_movies, year):
    import requests
    import pandas as pd
    from bs4 import BeautifulSoup
    movie_data= []

    # the 100 is testing for 100 results or two pages, use the total number desired or max of 10,000 due to URL routing format
    result_num=n_movies
    result_per_page=50
    reverseCount = round(result_num/result_per_page)
    count=1
    
    #Stop looping when we 
    while reverseCount != 0:
        # 
        URL= 'https://www.imdb.com/search/title/?title_type=feature&year={0}-01-01,{0}-12-31&sort=boxoffice_gross_us,desc&start={1}&ref_=adv_nxt'.format(year,count)
        page= requests.get(URL)
        soup = BeautifulSoup(page.content, 'html.parser')
        results= soup.find(id = 'pagecontent')
        movie_elements= results.find_all( class_= 'lister-item')

        count+=50
        reverseCount-=1
        columns= ['movie_id','title','year','content_rating','runtime','genres','rating','summary','director','main_actors','votes','revenue']

        for movie_element in movie_elements:
            try:
                #Get movie id
                movie_id= movie_element.find_all('a')[1]
                movie_id=str(movie_id)
                movie_id=movie_id[18:25]
                

                #Get title
                title=movie_element.find_all('a')[1].text

                #Get movie year
                year= movie_element.find('span', class_='lister-item-year text-muted unbold').text
                #Trim parentheses and other characters
                year=year[-5:-1]


                #Get content rating
                content_rating= movie_element.find('span', class_='certificate').text


                #Get runtime
                runtime= movie_element.find('span', class_='runtime').text


                #Get Genres
                genres= movie_element.find('span', class_='genre').text.strip()


                #Get rating
                rating= movie_element.find('div', class_='inline-block ratings-imdb-rating').text.strip()


                #Get movie summary
                summary= movie_element.find_all('p', class_='text-muted')
                summary=summary[1].text.strip()


                #Get director and main actors
                cast_elements= movie_element.find_all('a')
                director= cast_elements[13].text

                actors=cast_elements[14:18]
                actors_string= ""
                for actor in actors:
                    actor=actor.text
                    actors_string+= actor+", "
                main_actors=actors_string[:-2]
                
                #Get votes
                votes= movie_element.find_all('span')[33].text
                #Get Metascore
                metascore= movie_element.find('div', class_='inline-block ratings-metascore').text.strip()[:2]
                #Get gross revenue
                revenue= movie_element.find_all('span')[36].text
            except:
                # Fill with empty string if value not available
                movie_id= ''
                title= ''
                year= ''
                content_rating= ''
                runtime= ''
                genres= ''
                rating= ''
                summary= ''
                director= ''
                main_actors=''
                votes=''
                revenue=''

            
            # Add row of data into list of lists
            movie_data.append([movie_id,title,year,content_rating,runtime,genres,rating,summary,director,main_actors,votes,revenue])

    # Return a datframe made from the list of lists
    movie_df= pd.DataFrame(movie_data,columns=columns)
    return movie_df

# %%
# Retrieve top 150 movies for 2017
movies_2017=scrape_movies(n_movies=150, year=2017)
#Display top 5 movies
movies_2017.head(5)
# Out:
#   movie_id                                    title  year content_rating  \
# 0  2527336  Star Wars: Episode VIII - The Last Jedi  2017          PG-13
# 1  2771200                     Beauty and the Beast  2017             PG
# 2  0451279                             Wonder Woman  2017          PG-13
# 3  2283362           Jumanji: Welcome to the Jungle  2017          PG-13
# 4  3896198           Guardians of the Galaxy Vol. 2  2017          PG-13
#
#    runtime                      genres rating  \
# 0  152 min  Action, Adventure, Fantasy    7.0
# 1  129 min    Family, Fantasy, Musical    7.1
# 2  141 min  Action, Adventure, Fantasy    7.4
# 3  119 min   Action, Adventure, Comedy    6.9
# 4  136 min   Action, Adventure, Comedy    7.6
#
#                                              summary       director  \
# 0  Rey develops her newly discovered abilities wi...   Rian Johnson
# 1  A selfish Prince is cursed to become a monster...    Bill Condon
# 2  When a pilot crashes and tells of conflict in ...  Patty Jenkins
# 3  Four teenagers are sucked into a magical video...    Jake Kasdan
# 4  The Guardians struggle to keep together as a t...     James Gunn
#
#                                          main_actors    votes   revenue
# 0  Daisy Ridley, John Boyega, Mark Hamill, Carrie...  555,773  $620.18M
# 1     Emma Watson, Dan Stevens, Luke Evans, Josh Gad  269,507  $504.01M
# 2    Gal Gadot, Chris Pine, Robin Wright, Lucy Davis  543,440  $412.56M
# 3  Dwayne Johnson, Karen Gillan, Kevin Hart, Jack...  314,701  $404.52M
# 4  Chris Pratt, Zoe Saldana, Dave Bautista, Vin D...  560,528  $389.81M

# %%
# Retrieve data for the top 100 movies of 2018
movies_2018=scrape_movies(n_movies=100, year=2018)
#Display 5 movies
movies_2018.head(5)
# Out:
#   movie_id                           title  year content_rating  runtime  \
# 0  1825683                   Black Panther  2018          PG-13  134 min
# 1  4154756          Avengers: Infinity War  2018          PG-13  149 min
# 2  3606756                   Incredibles 2  2018             PG  118 min
# 3  4881806  Jurassic World: Fallen Kingdom  2018          PG-13  128 min
# 4  1477834                         Aquaman  2018          PG-13  143 min
#
#                          genres rating  \
# 0     Action, Adventure, Sci-Fi    7.3
# 1     Action, Adventure, Sci-Fi    8.4
# 2  Animation, Action, Adventure    7.6
# 3     Action, Adventure, Sci-Fi    6.2
# 4    Action, Adventure, Fantasy    6.9
#
#                                              summary       director  \
# 0  T'Challa, heir to the hidden but advanced king...   Ryan Coogler
# 1  The Avengers and their allies must be willing ...  Anthony Russo
# 2  The Incredibles family takes on a new mission ...      Brad Bird
# 3  When the island's dormant volcano begins roari...    J.A. Bayona
# 4  Arthur Curry, the human-born heir to the under...      James Wan
#
#                                          main_actors    votes   revenue
# 0  Chadwick Boseman, Michael B. Jordan, Lupita Ny...  615,854  $700.06M
# 1  Joe Russo, Robert Downey Jr., Chris Hemsworth,...  816,175  $678.82M
# 2  Craig T. Nelson, Holly Hunter, Sarah Vowell, H...  244,720  $608.58M
# 3  Chris Pratt, Bryce Dallas Howard, Rafe Spall, ...  262,282  $417.72M
# 4  Jason Momoa, Amber Heard, Willem Dafoe, Patric...  361,819  $335.06M
